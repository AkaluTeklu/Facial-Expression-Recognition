# %% [markdown]
# # Real-Time Facial Expression Recognition

# %%
from keras.models import load_model
from time import sleep
from tensorflow.keras.utils import img_to_array
from keras.preprocessing import image
import cv2
import numpy as np

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
emotion_model = load_model('emotion_detection_model_100epochs.h5')
class_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    labels = []
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        roi_gray = gray[y:y+h, x:x+w]
        # Resize the region of interest to match the model's input size
        roi_gray = cv2.resize(roi_gray, (224, 224), interpolation=cv2.INTER_AREA)

        # Get image ready for prediction
        roi = roi_gray.astype('float') / 255.0  
        roi = img_to_array(roi)
        roi = np.expand_dims(roi, axis=0)  

        preds = emotion_model.predict(roi)[0]  
        label = class_labels[preds.argmax()]  
        label_position = (x, y)
        cv2.putText(frame, label, label_position, cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
    cv2.imshow('Emotion Detector', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 24ms/step

# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from keras.models import load_model
from tensorflow.keras.utils import img_to_array

face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
emotion_model = load_model('emotion_detection_model_100epochs.h5')
class_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# Load emojis dynamically from the "emojis" directory

emojis_path = 'emojis'
emojis = {emotion: cv2.imread(os.path.join(emojis_path, f'{emotion.lower()}.png')) for emotion in class_labels}

cap = cv2.VideoCapture(0)


while True:
    ret, frame = cap.read()
    if not ret or frame is None:
        print("Error: Couldn't read frame")
        break
    labels = []

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_classifier.detectMultiScale(gray, 1.3, 5)

    preds = None

    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_gray = cv2.resize(roi_gray, (224, 224), interpolation=cv2.INTER_AREA)

        # Get image ready for prediction
        roi = roi_gray.astype('float') / 255.0
        roi = img_to_array(roi)
        roi = np.expand_dims(roi, axis=0)

        
        preds = emotion_model.predict(roi)[0]
        label = class_labels[preds.argmax()]
        
        emoji = emojis[label]

        emoji = cv2.resize(emoji, (w, h), interpolation=cv2.INTER_AREA)

       
        frame[y:y+h, x:x+w] = cv2.addWeighted(frame[y:y+h, x:x+w], 1, emoji, 0.7, 0)

       
        for i, (emotion, percentage) in enumerate(zip(class_labels, preds)):
            y_offset = i * 20 + 20
            cv2.putText(frame, f'{emotion}: {percentage*100:.2f}%', (x, y + h + y_offset),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)

    
    if preds is not None:
      
        plt.clf()
        plt.bar(class_labels, preds, color=['red', 'green', 'blue', 'cyan', 'magenta', 'yellow', 'orange'])
        plt.title('Emotion Recognition Histogram')
        plt.xlabel('Emotion')
        plt.ylabel('Percentage')
        plt.ylim([0, 1])
        plt.pause(0.1)

    cv2.imshow('Emotion Detector', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 24ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 74
#      71         plt.pause(0.1)
#      73     cv2.imshow('Emotion Detector', frame)
# ---> 74     if cv2.waitKey(1) & 0xFF == ord('q'):
#      75         break
#      77 # ... (remaining code)
#
# KeyboardInterrupt:
